# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
ts = pd.Series(randn(1000), index=date_range('1/1/2000', periods=1000))
ts = ts.cumsum()
ts.plot()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 ts = pd.Series(randn(1000), index=date_range('1/1/2000', periods=1000))
#       2 ts = ts.cumsum()
#       3 ts.plot()
#
# NameError: name 'randn' is not defined

# %%
import pandas as pd
import numpy as np

# Set a seed for reproducibility
np.random.seed(42)

# Generate a Pandas Series with 365 random points from a standard normal distribution
num_points = 365
date_range = pd.date_range(start='2023-01-01', periods=num_points)
random_data = pd.Series(np.random.randn(num_points), index=date_range)

# Display the result
print(random_data)
# Out:
# 2023-01-01    0.496714
# 2023-01-02   -0.138264
# 2023-01-03    0.647689
# 2023-01-04    1.523030
# 2023-01-05   -0.234153
#                 ...
# 2023-12-27    0.519347
# 2023-12-28    1.532739
# 2023-12-29   -0.108760
# 2023-12-30    0.401712
# 2023-12-31    0.690144
# Freq: D, Length: 365, dtype: float64

# %%
plt.plot(random_data)
