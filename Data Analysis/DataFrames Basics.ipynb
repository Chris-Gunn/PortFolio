# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('credit.csv',delimiter = ' ')
df.head()
# Out:
#     Income  Limit  Rating  Cards  Age  Education  Gender Student Married  \
# 0   14.891   3606     283      2   34         11    Male      No     Yes
# 1  106.025   6645     483      3   82         15  Female     Yes     Yes
# 2  104.593   7075     514      4   71         11    Male      No      No
# 3  148.924   9504     681      3   36         11  Female      No      No
# 4   55.882   4897     357      2   68         16    Male      No     Yes
#
#    Ethnicity  Balance
# 0  Caucasian      333
# 1      Asian      903
# 2      Asian      580
# 3      Asian      964
# 4  Caucasian      331

# %%
df.tail()
# Out:
#     Income  Limit  Rating  Cards  Age  Education  Gender Student Married  \
# 15  20.089   2525     200      3   57         15  Female      No     Yes
# 16  53.598   3714     286      3   73         17  Female      No     Yes
# 17  49.570   6384     448      1   28          9  Female      No     Yes
# 18  42.079   6626     479      2   44          9    Male      No      No
# 19  17.700   2860     235      4   63         16  Female      No      No
#
#            Ethnicity  Balance
# 15  African American        0
# 16  African American        0
# 17             Asian      891
# 18             Asian     1048
# 19             Asian       89

# %%
df.index
# Out:
# RangeIndex(start=0, stop=20, step=1)

# %%
df.columns
# Out:
# Index(['Income', 'Limit', 'Rating', 'Cards', 'Age', 'Education', 'Gender',
#        'Student', 'Married', 'Ethnicity', 'Balance'],
#       dtype='object')

# %%
  df.values
# Out:
# array([[14.891, 3606, 283, 2, 34, 11, ' Male', 'No', 'Yes', 'Caucasian',
#         333],
#        [106.025, 6645, 483, 3, 82, 15, 'Female', 'Yes', 'Yes', 'Asian',
#         903],
#        [104.593, 7075, 514, 4, 71, 11, ' Male', 'No', 'No', 'Asian', 580],
#        [148.924, 9504, 681, 3, 36, 11, 'Female', 'No', 'No', 'Asian',
#         964],
#        [55.882, 4897, 357, 2, 68, 16, ' Male', 'No', 'Yes', 'Caucasian',
#         331],
#        [80.18, 8047, 569, 4, 77, 10, ' Male', 'No', 'No', 'Caucasian',
#         1151],
#        [20.996, 3388, 259, 2, 37, 12, 'Female', 'No', 'No',
#         'African American', 203],
#        [71.408, 7114, 512, 2, 87, 9, ' Male', 'No', 'No', 'Asian', 872],
#        [15.125, 3300, 266, 5, 66, 13, 'Female', 'No', 'No', 'Caucasian',
#         279],
#        [71.061, 6819, 491, 3, 41, 19, 'Female', 'Yes', 'Yes',
#         'African American', 1350],
#        [63.095, 8117, 589, 4, 30, 14, ' Male', 'No', 'Yes', 'Caucasian',
#         1407],
# ...

# %%
df.describe()
# Out:
#            Income        Limit      Rating      Cards        Age  Education  \
# count   20.000000    20.000000   20.000000  20.000000  20.000000  20.000000
# mean    54.685150  5372.650000  398.200000   2.700000  56.950000  12.600000
# std     36.949532  2247.537279  149.418381   1.128576  18.377546   3.299123
# min     14.891000  1311.000000  138.000000   1.000000  28.000000   7.000000
# 25%     19.852750  3366.000000  268.250000   2.000000  40.000000   9.750000
# 50%     51.584000  5846.000000  421.000000   3.000000  60.000000  12.500000
# 75%     73.601000  6960.250000  511.250000   3.250000  71.500000  15.250000
# max    148.924000  9504.000000  681.000000   5.000000  87.000000  19.000000
#
#            Balance
# count    20.000000
# mean    591.700000
# std     483.297239
# min       0.000000
# 25%     189.250000
# 50%     456.500000
# 75%     985.000000
# max    1407.000000

# %%
school = df[['Age','Education']] #2D array

# %%
df[(df['Age']>30) & (df['Education']<20)]
# Out:
#      Income  Limit  Rating  Cards  Age  Education  Gender Student Married  \
# 0    14.891   3606     283      2   34         11    Male      No     Yes
# 1   106.025   6645     483      3   82         15  Female     Yes     Yes
# 2   104.593   7075     514      4   71         11    Male      No      No
# 3   148.924   9504     681      3   36         11  Female      No      No
# 4    55.882   4897     357      2   68         16    Male      No     Yes
# 5    80.180   8047     569      4   77         10    Male      No      No
# 6    20.996   3388     259      2   37         12  Female      No      No
# 7    71.408   7114     512      2   87          9    Male      No      No
# 8    15.125   3300     266      5   66         13  Female      No      No
# 9    71.061   6819     491      3   41         19  Female     Yes     Yes
# 11   15.045   1311     138      3   64         16    Male      No      No
# 12   80.616   5308     394      1   57          7  Female      No     Yes
# ...

# %%
plt.plot(school)
